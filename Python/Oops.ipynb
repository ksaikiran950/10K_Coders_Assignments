# %%
class car:
    brand="BMW"
    eng=1
    mileage=15
    speed=100
    color="Blue"
    # print(brand,eng,mileage,speed,color)

# car1=car()
# print(car1brand)
# car2=car()
# car2mileage=20
# print(car2mileage)
# car3=car()
# car3color="Green"
# print(car3color)
# car2brand="mercedes"
# print(car2brand)
    def __init__():
        pass
    def __init__(,color):
        color=color

    
car1=car("red")
print(car1color)
print(car1eng)
# Out:
# red
# 1

# %%
class ksk:
    batch="30S"
    def __init__(,name,phone,course):
        name=name
        phone=phone
        course=course
        print("ad")


s1=ksk("siva",789456123,"py")
print(s1name)
# Out:
# siva

# %%
class greeting:
    def visit():
        print("hello sir!")
    def exit():
        print("TQ visit again !")

g1=greeting()
g1visit()
g1exit()
# Out:
# hello sir!
# TQ visit again !

# %%
class greeting:
    def visit():
        print("hello sir!")
    def exit():
        print("TQ visit again !")

g1=greeting()
g1visit()
g1exit()
# Out:
# hello sir!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 g1=greeting()
#       8 g1.visit()
# ----> 9 g1.exit()
#
# TypeError: greeting.exit() takes 0 positional arguments but 1 was given

# %%
class greeting:
    def __init__(,name):
        name=name
    def visit(,name):
        print(f"hello {name}   sir!  ")
    def exit():
        print(f"{name} TQ visit again !")

g1=greeting("sai")
g1visit("kiran")
g1exit()
# Out:
# hello kiran   sir!
# sai TQ visit again !

# %%
class calci:
    def __init__(,first,second):
        first=first
        second=second
    def add():
        return first+second
    def sub(,a,b):
        return a-b
    
c1=calci(10,20)
c2=calci(100,88)
print(c1add())
print(c2sub(1,2))
# Out:
# 30
# -1

# %%
class Calci:
    def add(a,b):
        return a+b
    def sub(a,b):
        return a-b
    def mul(a,b):
        return a*b
    def div(a,b):
        return a/b
    def rem(a,b):
        return a%b




a,b=100,20
print(Calci.add(a,b))
print(Calci.sub(a,b))
print(Calci.mul(a,b))
print(Calci.div(a,b))
print(Calci.rem(a,b))
# Out:
# 120
# 80
# 2000
# 5.0
# 0

# %%
class Calci:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def add(self):
        return self.a + self.b

    def sub(self):
        return self.a - self.b

    def mul(self):
        return self.a * self.b

    def div(self):
        return self.a / self.b

    def rem(self):
        return self.a % self.b


# create object
s1 = Calci(100, 20)

print("Addition:", s1.add())
print("Subtraction:", s1.sub())
print("Multiplication:", s1.mul())
print("Division:", s1.div())
print("Remainder:", s1.rem())
# Out:
# Addition: 120
# Subtraction: 80
# Multiplication: 2000
# Division: 5.0
# Remainder: 0

# %%
class Calci:

    def add(self,a,b):
        return a + b

    def sub(self,a,b):
        return a - b

    def mul(self,a,b):
        return a * b

    def div(self,a,b):
        return a / b

    def rem(self,a,b):
        return a % b


print("Choose operation: ")
print("1. Add\n2. Sub\n3. Mul\n4. Div\n5. Rem\n6. Exit")

s1 = Calci()

while True:
    n = int(input("\nEnter your option: "))

    if n == 6:
        print("Exit")
        break

    a, b = map(int, input("Enter two values : ").split())

    if n == 1:
        print(s1.add(a,b))
    elif n == 2:
        print(s1.sub(a,b))
    elif n == 3:
        print(s1.mul(a,b))
    elif n == 4:
        print(s1.div(a,b))
    elif n == 5:
        print(s1.rem(a,b))
    else:
        print("Invalid choice. Please try again.")
# Out:
# Choose operation:
# 1. Add
# 2. Sub
# 3. Mul
# 4. Div
# 5. Rem
# 6. Exit
# Result: 50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 25
#      22 s1 = Calci()
#      24 while True:
# ---> 25     n = int(input("\nEnter your option: "))
#      27     if n == 6:
#      28         print("Exiting calculator. Goodbye!")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
class Calci:
    print(f"\nHello {s1.name}! Welcome ")

    print("Choose operation: ")
    print("1. Add\n2. Sub\n3. Mul\n4. Div\n5. Rem\n6. Exit\n7. Show Name")
    
    def __init__(self, name):
        self.name = name  

    def add(self, a, b):
        return a + b

    def sub(self, a, b):
        return a - b

    def mul(self, a, b):
        return a * b

    def div(self, a, b):
        return a / b

    def rem(self, a, b):
        return a % b


name = input("Enter your name: ")

s1 = Calci(name)
a, b = map(int, input("Enter two values : ").split())

while True:
    n = int(input("\nEnter your option: "))
    
    if n == 1:
        print(s1.add(a, b))
    elif n == 2:
        print(s1.sub(a, b))
    elif n == 3:
        print(s1.mul(a, b))
    elif n == 4:
        print(s1.div(a, b))
    elif n == 5:
        print(s1.rem(a, b))
    
    elif n == 6:
        print(f"Exit")
        break
    elif n == 7:
        print(f"Name: {s1.name}")
        continue
    else:
        print("Invalid choice. Please try again.")
# Out:
# Hello kiran! Welcome
# Choose operation:
# 1. Add
# 2. Sub
# 3. Mul
# 4. Div
# 5. Rem
# 6. Exit
# 7. Show Name
# 15
# 3
# 54
# 1.5
# 3
# Name: sai
# Exit

# %%
class Calci:

    print("Choose operation: ")
    print("1. Add\n2. Sub\n3. Mul\n4. Div\n5. Rem\n6. Exit\n7. Show Name")
    
    def __init__(self, name):
        self.name = name  

    def add(self, a, b):
        return a + b

    def sub(self, a, b):
        return a - b

    def mul(self, a, b):
        return a * b

    def div(self, a, b):
        return a / b

    def rem(self, a, b):
        return a % b


name = input("Enter your name: ")

s1 = Calci(name)

print(f"\nHello {s1.name}! Welcome ")

while True:
    n = int(input("\nEnter your option: "))   

    if n == 1:
        a, b = map(int, input("Enter two values : ").split())
        print(s1.add(a, b))
    elif n == 2:
        a, b = map(int, input("Enter two values : ").split())
        print(s1.sub(a, b))
    elif n == 3:
        a, b = map(int, input("Enter two values : ").split())
        print(s1.mul(a, b))
    elif n == 4:
        a, b = map(int, input("Enter two values : ").split())
        print(s1.div(a, b))
    elif n == 5:
        a, b = map(int, input("Enter two values : ").split())
        print(s1.rem(a, b))    
    elif n == 6:
        print(f"Exit")
        break
    elif n == 7:
        print(f"Name: {s1.name}")
        continue
    else:
        print("Invalid choice. Please try again.")
# Out:
# Choose operation:
# 1. Add
# 2. Sub
# 3. Mul
# 4. Div
# 5. Rem
# 6. Exit
# 7. Show Name
#
# Hello raj! Welcome
# 5
# Name: raj
# Exit

# %%
class calci:
    @staticmethod
    def add(a,b):
        print(a+b)

c1=calci()
c1.add(2,3)
# Out:
# 5

# %%
class car:
    def __init__(self):
        self.acc=False
        self.clu=False
        self.brk=False
    def start(self):
        self.acc=True
        self.clu=True
        print("car starts...")

car1=car()
car1.start()
# Out:
# car starts...

# %%
from abc import abstractmethod
class car:
    def __init__(self):
        self.acc=False
        self.clu=False
        self.brk=False
    @abstractmethod
    def start():
        self.acc=True
        self.clu=True
        print("car starts...")

car1=car()
car1.start()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 14
#      11         print("car starts...")
#      13 car1=car()
# ---> 14 car1.start()
#
# TypeError: car.start() takes 0 positional arguments but 1 was given

# %% [markdown]
# from abc import ABC, abstractmethod
#
# class BaseModel(ABC):
#     @abstractmethod
#     def train(self, data):
#         pass
#
#     @abstractmethod
#     def predict(self, input_data):
#         pass

# %%
class bankaccount:
    def __init__(self,name,accno,pin,balance=0):
        self.name=name
        self.accno=accno
        self.pin=pin
        self.balance=balance
    def deposit(self):
        amount=int(input("enter amount"))
        if amount>0:
            self.balance+=amount
            print(f"{amount} has deposited in your account")
        else:
            print("invalid amount")
    def withdraw(self):
        amount=int(input("enter amount"))
        if 0<amount<=self.balance:
            self.balance-=amount
            print(f"{amount} has withdrawed")
        else:
            print("invalid amount")
    def checkbalance(self):
        print(f"your balance is {self.balance}")
    def menu(self):
        
        while True:
            print("1.deposit")
            print("2.withdraw")
            print("3.balance")
            print("4.logout")
            choice=int(input("enter your choice"))
            if choice==1:
                self.deposit()
            elif choice==2:
                self.withdraw()
            elif choice==3:
                self.checkbalance()
            elif choice==4:
                print("thankyou logged out")
                break
class bank:
    def __init__(self):
        self.accounts=[]
    def createaccount(self):
        name=input("enter your name:")
        accno=input("enter your account no")
        pin=input("enter 4 digit pin")
        account=bankaccount(name,accno,pin)
        self.accounts.append(account)
        print("account created succussfully")
    def login(self):
        accno=input("enter your accno")
        pin=input("enter your 4-digit pin")
        for account in  self.accounts:
            if account.accno==accno and account.pin==pin:
                print(f"welcome{account.name}")
                account.menu()
                return 
        
        print("invalid  pin or accno")
        
banks=bank()
while True:
    print("welcome to python bank")
    print("1. create account")
    print("2.login")
    print("3.exit")
    choice=int(input("enter your choice"))
    if choice==1:
        banks.createaccount()
    elif choice==2:
        banks.login()
    elif choice==3:
        print("thankyou visit aagain")
        break
    else:
        print("enter valid choice")
# Out:
# welcome to python bank
# 1. create account
# 2.login
# 3.exit
# account created succussfully
# welcome to python bank
# 1. create account
# 2.login
# 3.exit
# invalid  pin or accno
# welcome to python bank
# 1. create account
# 2.login
# 3.exit
# account created succussfully
# welcome to python bank
# 1. create account
# 2.login
# 3.exit
# welcome12
# 1.deposit
# 2.withdraw
# 3.balance
# 4.logout
# 500 has deposited in your account
# 1.deposit
# 2.withdraw
# 3.balance
# 4.logout
# 499 has withdrawed
# 1.deposit
# 2.withdraw
# 3.balance
# 4.logout
# your balance is 1
# 1.deposit
# 2.withdraw
# 3.balance
# 4.logout
# your balance is 1
# 1.deposit
# 2.withdraw
# 3.balance
# 4.logout
# thankyou logged out
# welcome to python bank
# 1. create account
# 2.login
# 3.exit
# enter valid choice
# welcome to python bank
# 1. create account
# 2.login
# 3.exit
# thankyou visit aagain

# %%
class BankAccount:
    def __init__(self, name, acc_no, balance=0):
        self.name = name
        self.acc_no = acc_no
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"₹{amount} deposited successfully!")
        else:
            print("Invalid deposit amount!")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"₹{amount} withdrawn successfully!")
        else:
            print("Insufficient balance or invalid amount!")

    def check_balance(self):
        #print(f"Account Holder: {self.name}")
        #print(f"Account Number: {self.acc_no}")
        print(f"Current Balance: ₹{self.balance}")

# Dictionary to store multiple accounts
accounts = {}

def create_account():
    name = input("Enter your name: ")
    acc_no = input("Enter a new account number: ")

    if acc_no in accounts:
        print("Account already exists!")
    else:
        accounts[acc_no] = BankAccount(name, acc_no)
        print(f"Account created successfully for {name}!")

def deposit_money():
    acc_no = input("Enter your account number: ")
    if acc_no in accounts:
        amount = float(input("Enter amount to deposit: "))
        accounts[acc_no].deposit(amount)
    else:
        print("Account not found!")

def withdraw_money():
    acc_no = input("Enter your account number: ")
    if acc_no in accounts:
        amount = float(input("Enter amount to withdraw: "))
        accounts[acc_no].withdraw(amount)
    else:
        print("Account not found!")

def check_account_balance():
    acc_no = input("Enter your account number: ")
    if acc_no in accounts:
        accounts[acc_no].check_balance()
    else:
        print("Account not found!")

def main():
    while True:
        print("\n----- Simple Banking System -----")
        print("1. Create Account")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Check Balance")
        print("5. Exit")
        
        choice = input("Enter your choice (1-5): ")

        if choice == '1':
            create_account()
        elif choice == '2':
            deposit_money()
        elif choice == '3':
            withdraw_money()
        elif choice == '4':
            check_account_balance()
        elif choice == '5':
            print("Thank you for using our banking system!")
            break
        else:
            print("Invalid choice! Please try again.")

# Run the program
main()
# Out:
# ----- Simple Banking System -----
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Exit
# Invalid choice! Please try again.
#
# ----- Simple Banking System -----
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Exit
# Invalid choice! Please try again.
#
# ----- Simple Banking System -----
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Exit
# Account created successfully for sai!
#
# ----- Simple Banking System -----
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Exit

# %%
class Details:
    details={}
    def __init__(self,name,age,contact,roll_no):
        self.name=name
        self.age=age
        self.contact=contact
        self.roll_no=roll_no

class student:
    def __init__(self):
        self.students=[]
    

    def add_stu(self):
        roll_no=input("Enter your roll number")
        name=input("Enter your Name")
        age=int(input("enter your age"))
        contact=int(input("enter your contact"))

        s=Details(name,age,contact,roll_no)

        self.students.append(s)
        print("Students added successfully !")
